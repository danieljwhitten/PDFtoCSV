# %% [markdown]
# # Guide for Installation and Use

# %% [markdown]
# ## Prerequisites
# ### Anaconda & Jupyter Notebooks
# We recommend using this program via the [Anaconda Data Science Platform](https://www.anaconda.com/). This includes Jupyter Notebooks, and you likely already have it installed if you are viewing this file.
# This program can also be run via any Python interpreter, including from the command line, if you have the technical knowledge to do so.
#
# ### Python 3
# This program is written using the latest version of Python to date. To ensure you are ready to run it, ensure that the top right corner of your Jupyter Notebook says `Python 3`. If it does not, try to change it by going to the `Kernel` menu, choosing `Change Kernel`, then `Python 3`. If you do not see this option, you may need to download the latest version of Anaconda [here](https://www.anaconda.com/distribution/).
#
# **With that, you should be able to follow the steps below and get going within a few minutes!**

# %% [markdown]
# ## Installation
#
# The following steps are required before the program is run for the first time. They do not need to be repeated again on the same computer.
#
# ### 1. Install Tesseract
# Tesseract is the tool this program uses to read text from pages that do not have machine-readable text. It is is a free, open-source program (sponsored by Google) that performs Optical Character Recognition (OCR). It must be installed first for this program to work properly. More information about Tesseract OCR can be found [here](https://github.com/tesseract-ocr/tesseract/blob/master/README.md).
# #### Windows
# 1. Download the Tesseract OCR installer [here](https://github.com/UB-Mannheim/tesseract/wiki).
# 2. Run the .exe file once it has been downloaded.
# 3. Accept all default options.
#
# #### Mac
# The easiest way is to install via [Homebrew](https://brew.sh/), a handy installer that works to easily install all kinds of usefuly programs, in addition to Tesseract OCR.
#   * Open Terminal (Press Command + Space, type "Terminal", press Enter)
#   * Paste: ```/usr/bin/ruby -e "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/master/install)"```
#   * Press Enter
#   * Press Enter again
#   * Enter your computer password to authorize installation when prompted
#   * Homebrew has successfully installed once you  see `==> Installation successful!`
#   * Paste the following: `brew install tesseract`
#   * Press Enter
#
# For experienced users, see [here](https://github.com/tesseract-ocr/tesseract/wiki#macos) for other installation options.
#
# #### Linux
# If your distribution uses `apt`, like Ubuntu, the following should install Tesseract OCR:
# `sudo apt install tesseract-ocr`
# See [here](https://github.com/tesseract-ocr/tesseract/wiki#linux) for more detailed instructions for a wide variety of distributions

# %% [markdown]
# ### 2. Prepare Python

# %% [markdown]
# The cell below installs the Python programs required for this program to run.
# Execute the cell by clicking on it and pressing Shift+Enter.

# %%
# %run "installDependencies.py"
from IPython.core.display import HTML
HTML("<script>Jupyter.notebook.kernel.restart()</script>")

# %% [markdown]
# If the output above indicates `All packages are installed`, you are good to start using the program!
#
# If not, try opening your command line (Windows: Open the program "Command Prompt", Mac: Open the program "Terminal") and paste the following, then press Enter: `python -m pip install unidecode pytesseract PyMuPDF natsort`

# %% [markdown]
# ## How to Use the Program
#
# ### Prepare Your PDF Input
#
# #### Legible Black and White Typed Text
# It works best with PDF files that have clearly legible typed black text on a white background. The majority of the text should be in the same font and the same size. The program will still try to process files with coloured backgrounds or various non-standard fonts, but the quality of the output may be low.
#
# #### Clearly Labelled Files
# The output will be one single CSV file (can be opened as a spreadsheet in Microsoft Excel). The text from each page of each document will be included on a separate line. Each line will have:
# 1. The path of the source file, including preceding folders and the name of the file
#   * Eg. "path/to/folder/with/PDF/2019/January/1Jan2019.pdf"
# 2. The page number, relative to each file
# 3. The number of words captured from the page
# 4. The text of the page
#
# Because of this format, it is most convenient for you to take the time to name your folders and files descriptively. The program processes the files in the same order that they appear on your computer, when sorted by file name. However, if your folders are randomly or inconsistantly named, it will make it harder to sort and analyze the data
#
#
# #### Awareness of Time Required
# This program extracts text in two different ways. First, it tries to see if any text is already embedded in the PDF (i.e., the PDF is "machine readable"). If there is no text embedded, the program then uses [Tesseract OCR](https://github.com/UB-Mannheim/tesseract/wiki) to read the letters on the page as plain text. It is not crucial to understand how this works, but it will make a different for how long the file(s) will take to process.
# * Machine readable PDF: ~0.009 seconds/page
# * Non-machine readable: ~1 second/100 words on page
#
# While this does not make a large difference if the file has only a few pages, the time difference increases with larger files, and can take days for 20,000+ pages. In order to accurately estimate the time required, open up your PDF files and determine whether they are machine readable or not. The easiest way is to search for a word you know is in the file. If your PDF reader finds the word, it has "read" the file, and the file is machine readable. If it does not, it is likely not machine readanble, and will require OCR. Another way of checking is to try to highligh the text with your mouse, if it highlights the lines of text, the page is likely machine readable. If it highlights the entire page as one large box, it is likely not.
# For larger files, it is common to have some non-machine readable files distributed within machine readable pages. This is common with advertisements in newspapers, for example. The program will process any machine readble file accordingly, and only use OCR on individual pages when necessary, so such file should still be processed relatively quickly.
# In order to optimize the speed of processing, minimize other tasks being performed by your computer at the same time. Computers have limited processing resources, so watching videos, surfing the internet, or writing in a word processor will all negatively impact the processing time for your files. This is not to say that one cannot multitask while processing files, and the effect is only noticable on large batches of non-machine readable files that are continually processing for hours or days at a time.
#
# ### Run the Program
#
# #### In Jupyter Notebooks
# In Jupyter Notebooks, you can either use the cell below (Under "Ready to Go!"), or navigate to the folder where you downloaded this program and create a new notebook.
# In a new cell, paste: `%run PDFtoCSV.py "path/to/folder/with/PDF"`
#
# #### From Command Line
# If you do not want to run the program via Jupyter Notebooks, it is possible to run via the command line (Command Prompt or Terminal), by running the following command `python path/to/download/PDFtoCSV.py /path/to/folder/with/PDFs`, replacing the first path with the location of this program and the second with the location of your PDFs.

# %% [markdown]
# ## Ready to Go!

# %% [markdown]
# You are ready to start extracting text from your PDF files!
# The simplist way is to use the cell below. Simply replace the section in quotation marks with the path to the file or folder you want to convert. For instructions on copying and pasting paths, see below.

# %%
# %run PDFtoCSV.py "/Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY"
# Out:
# mupdf: expected object number
# mupdf: invalid key in dict
# mupdf: cannot parse indirect reference in array
# mupdf: invalid key in dict
# mupdf: invalid key in dict
# mupdf: invalid key in dict
# mupdf: invalid key in dict
# mupdf: invalid key in dict
# mupdf: invalid key in dict
# mupdf: non-page object in page tree
# mupdf: cannot find startxref
# mupdf: object out of range (48 0 R); xref size 46
# mupdf: non-page object in page tree
# mupdf: cannot find startxref
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: non-page object in page tree
# Processing all PDF files in folder /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY (89 Files)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/001 Dailly Trust Tuesday May 1, 2007 Vol. 16 No. 37.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 001 Dailly Trust Tuesday May 1, 2007 Vol. 16 No. 37.pdf in 717.785 seconds (56 pages, 66540 words, 12.818 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/002 Daily Trust Wednesday May 2, 2007 Vol. 16 No. 38.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 002 Daily Trust Wednesday May 2, 2007 Vol. 16 No. 38.pdf in 626.539 seconds (56 pages, 64886 words, 11.188 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/003 Daily Trust Thursday May 3, 2007 Vol. 16 No.39.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 003 Daily Trust Thursday May 3, 2007 Vol. 16 No.39.pdf in 616.392 seconds (56 pages, 69790 words, 11.007 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/004 Daily Trust Friday May 4, 2007 Vol. 16 No. 40.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 004 Daily Trust Friday May 4, 2007 Vol. 16 No. 40.pdf in 589.83 seconds (56 pages, 66480 words, 10.533 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/005 Weekly Trust, Saturday, May 5, 2007 vol. 10 No 27.pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 005 Weekly Trust, Saturday, May 5, 2007 vol. 10 No 27.pdf in 679.797 seconds (64 pages, 81493 words, 10.622 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/006 Sunday Trust, Vol. 1 No. 32 May 6, 2007 Rabiul Thani 19 , 1428 A. H..pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 006 Sunday Trust, Vol. 1 No. 32 May 6, 2007 Rabiul Thani 19 , 1428 A. H..pdf in 700.977 seconds (64 pages, 74537 words, 10.953 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/007 Daily Trust Monday May 7, 2007 Vol. 16 No. 41.pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 007 Daily Trust Monday May 7, 2007 Vol. 16 No. 41.pdf in 637.753 seconds (64 pages, 65009 words, 9.965 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/008 Daily Trust Tuesday May 8, 2007 Vol. 16 No. 42.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 008 Daily Trust Tuesday May 8, 2007 Vol. 16 No. 42.pdf in 659.983 seconds (56 pages, 70665 words, 11.785 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/009 Daily Trust Wednesday May 9, 2007 Vol. 16 No. 43.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 009 Daily Trust Wednesday May 9, 2007 Vol. 16 No. 43.pdf in 645.355 seconds (56 pages, 63572 words, 11.524 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/010 Daily Trust Thursday May 10, 2007 Vol. 16 No. 44.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 010 Daily Trust Thursday May 10, 2007 Vol. 16 No. 44.pdf in 637.09 seconds (56 pages, 64472 words, 11.377 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/011 Daily Trust Friday May 11, 2007 Vol. 16 No. 45.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 011 Daily Trust Friday May 11, 2007 Vol. 16 No. 45.pdf in 631.708 seconds (56 pages, 59473 words, 11.28 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/012 Weekly Trust, Saturday, May 12, 2007 vol.10 No 28.pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 012 Weekly Trust, Saturday, May 12, 2007 vol.10 No 28.pdf in 732.228 seconds (64 pages, 74921 words, 11.441 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/013 Sunday Trust, Vol. 1 No. 33 May 13, 2007 Rabiul Thani 26, 1428 A .H..pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 013 Sunday Trust, Vol. 1 No. 33 May 13, 2007 Rabiul Thani 26, 1428 A .H..pdf in 783.939 seconds (64 pages, 79239 words, 12.249 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/014 Daily Trust Monday May 14, 2007 Vol. 16 No. 46.pdf (72 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 014 Daily Trust Monday May 14, 2007 Vol. 16 No. 46.pdf in 730.365 seconds (72 pages, 60746 words, 10.144 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/015 Daily Trust Tuesday May 15, 2007 Vol. 16 No. 47.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 015 Daily Trust Tuesday May 15, 2007 Vol. 16 No. 47.pdf in 671.794 seconds (56 pages, 63821 words, 11.996 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/016 Daily Trust Wednesday May 16, 2007 Vol. 16 No. 47.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 016 Daily Trust Wednesday May 16, 2007 Vol. 16 No. 47.pdf in 693.449 seconds (56 pages, 63064 words, 12.383 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/017 Daily Trust Thursday May 17, 2007 Vol. 16 No. 48.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 017 Daily Trust Thursday May 17, 2007 Vol. 16 No. 48.pdf in 637.48 seconds (56 pages, 61096 words, 11.384 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/018 Daily Trust Friday May 18, 2007 Vol. 16 No. 49.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 018 Daily Trust Friday May 18, 2007 Vol. 16 No. 49.pdf in 660.467 seconds (56 pages, 64685 words, 11.794 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/019 Weekly Trust, Saturday, May 19, 2007 vol. 10 No 29.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 019 Weekly Trust, Saturday, May 19, 2007 vol. 10 No 29.pdf in 792.382 seconds (56 pages, 71614 words, 14.15 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/020 Sunday Trust, Vol. 1 No. 34 May 20, 2007 Jumada Ula 4, 1428 A . H..pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 020 Sunday Trust, Vol. 1 No. 34 May 20, 2007 Jumada Ula 4, 1428 A . H..pdf in 825.406 seconds (64 pages, 82573 words, 12.897 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/021 Daily Trust Monday May 21, 2007 Vol. 16 No. 51.pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 021 Daily Trust Monday May 21, 2007 Vol. 16 No. 51.pdf in 716.397 seconds (64 pages, 66665 words, 11.194 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/022 Daily Trust Tuesday May 22, 2007 Vol. 16 No. 52.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 022 Daily Trust Tuesday May 22, 2007 Vol. 16 No. 52.pdf in 675.183 seconds (56 pages, 64739 words, 12.057 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/023 Daily Trust Wednesday May 23, 2007 Vol. 16 No. 53.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 023 Daily Trust Wednesday May 23, 2007 Vol. 16 No. 53.pdf in 663.072 seconds (56 pages, 62887 words, 11.841 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/024 Daily Trust Thursday May 24, 2007 Vol. 16 No. 54.pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 024 Daily Trust Thursday May 24, 2007 Vol. 16 No. 54.pdf in 663.101 seconds (64 pages, 68877 words, 10.361 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/025 Daily Trust Friday May 25, 2007 Vol. 16 No. 55.pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 025 Daily Trust Friday May 25, 2007 Vol. 16 No. 55.pdf in 654.524 seconds (64 pages, 71807 words, 10.227 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/026 Weekly Trust, Saturday, May 26, 2007 vol. 10 No 30.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 026 Weekly Trust, Saturday, May 26, 2007 vol. 10 No 30.pdf in 601.93 seconds (56 pages, 71297 words, 10.749 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/027 Sunday Trust, Vol. 1 No. 35 May 27 , 2007 Jumada Ula 11, 1428 A. H..pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 027 Sunday Trust, Vol. 1 No. 35 May 27 , 2007 Jumada Ula 11, 1428 A. H..pdf in 731.668 seconds (64 pages, 84928 words, 11.432 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/028 Daily Trust Monday May 28, 2007 Vol. 16 No. 56.pdf (65 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 028 Daily Trust Monday May 28, 2007 Vol. 16 No. 56.pdf in 603.876 seconds (65 pages, 58245 words, 9.29 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/029 Daily Trust Tuesday May 29, 2007 Vol. 16 No. 57.pdf (72 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 029 Daily Trust Tuesday May 29, 2007 Vol. 16 No. 57.pdf in 575.292 seconds (72 pages, 48275 words, 7.99 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/05-MAY 2007/031 Daily Trust Thursday May 31, 2007 Vol. 16 No. 59.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 031 Daily Trust Thursday May 31, 2007 Vol. 16 No. 59.pdf in 566.826 seconds (56 pages, 58634 words, 10.122 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/001 Daily Trust Friday June 1, 2007 Vol. 16 No. 60.pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 001 Daily Trust Friday June 1, 2007 Vol. 16 No. 60.pdf in 639.177 seconds (64 pages, 68674 words, 9.987 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/003 Sunday Trust, Vol. 1 No. 36 June 3, 2007 Jumada Ula 18, 1428 A.H..pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 003 Sunday Trust, Vol. 1 No. 36 June 3, 2007 Jumada Ula 18, 1428 A.H..pdf in 6.013 seconds (64 pages, 70292 words, 0.094 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/004 Daily Trust Monday June 4, 2007 Vol. 16 No. 61.pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 004 Daily Trust Monday June 4, 2007 Vol. 16 No. 61.pdf in 611.104 seconds (64 pages, 64074 words, 9.549 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/005 Daily Trust Tuesday June 5, 2007 Vol. 16 No. 62.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 005 Daily Trust Tuesday June 5, 2007 Vol. 16 No. 62.pdf in 586.024 seconds (56 pages, 63787 words, 10.465 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/006 Daily Trust Wednesday June 6, 2007 Vol. 16 No. 63.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 006 Daily Trust Wednesday June 6, 2007 Vol. 16 No. 63.pdf in 592.51 seconds (56 pages, 64905 words, 10.581 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/007 Daily Trust Thursday June 7, 2007 Vol. 16 No. 64.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 007 Daily Trust Thursday June 7, 2007 Vol. 16 No. 64.pdf in 616.884 seconds (56 pages, 66150 words, 11.016 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/008 Daily Trust Friday June 8, 2007 Vol. 16 No. 65.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 008 Daily Trust Friday June 8, 2007 Vol. 16 No. 65.pdf in 611.319 seconds (56 pages, 68665 words, 10.916 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/009 Weekly Trust, Saturday, June 9, 2007 vol. 10 No 32.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 009 Weekly Trust, Saturday, June 9, 2007 vol. 10 No 32.pdf in 571.682 seconds (56 pages, 70673 words, 10.209 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/010 Sunday Trust, Vol. 1 No. 37 June 10, 2007 Jumada Ula 25, 1428 A .H..pdf (64 pages)
# Progress: 0%|====================|100%
# Completed 010 Sunday Trust, Vol. 1 No. 37 June 10, 2007 Jumada Ula 25, 1428 A .H..pdf in 1.179 seconds (64 pages, 66678 words, 0.018 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/011 Daily Trust Monday June 11, 2007 Vol. 16 No. 66.pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 011 Daily Trust Monday June 11, 2007 Vol. 16 No. 66.pdf in 680.228 seconds (64 pages, 75413 words, 10.629 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/012 Daily Trust Tuesday June 12, 2007 Vol. 16 No. 67.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 012 Daily Trust Tuesday June 12, 2007 Vol. 16 No. 67.pdf in 590.745 seconds (56 pages, 68153 words, 10.549 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/013 Daily Trust Wednesday June 13, 2007 Vol. 16 No. 68.pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 013 Daily Trust Wednesday June 13, 2007 Vol. 16 No. 68.pdf in 726.635 seconds (64 pages, 81557 words, 11.354 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/014 Daily Trust Thursday June 14, 2007 Vol. 16 No. 69.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 014 Daily Trust Thursday June 14, 2007 Vol. 16 No. 69.pdf in 560.093 seconds (56 pages, 59690 words, 10.002 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/015 Daily Trust Friday June 15, 2007 Vol. 16 No. 70.pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 015 Daily Trust Friday June 15, 2007 Vol. 16 No. 70.pdf in 663.068 seconds (64 pages, 71673 words, 10.36 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/016 Weekly Trust, Saturday, june 16, 2007 vol. 10 No 33.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 016 Weekly Trust, Saturday, june 16, 2007 vol. 10 No 33.pdf in 599.506 seconds (56 pages, 74897 words, 10.705 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/017 Sunday Trust, Vol. 1 No. 38 June 17,2007 Jumada Akhir 2, 1428 A . H..pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 017 Sunday Trust, Vol. 1 No. 38 June 17,2007 Jumada Akhir 2, 1428 A . H..pdf in 4.035 seconds (64 pages, 66731 words, 0.063 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/018 Daily Trust Monday June 18, 2007 Vol. 16 No. 71.pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 018 Daily Trust Monday June 18, 2007 Vol. 16 No. 71.pdf in 662.278 seconds (64 pages, 71509 words, 10.348 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/019 Daily Trust Tuesday June 19, 2007 Vol. 16 No. 72.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 019 Daily Trust Tuesday June 19, 2007 Vol. 16 No. 72.pdf in 624.697 seconds (56 pages, 70532 words, 11.155 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/06-JUNE 2007/020 Daily Trust Wednesday June 20, 2007 Vol. 16 No. 73.pdf (59 pages)
# Progress: 0%|
# mupdf: cannot find startxref
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: non-page object in page tree
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Read 92 words from page 29/59 in 2.388 seconds
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# Read 0 words from page 30/59 in 0.488 seconds
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# Read 0 words from page 31/59 in 0.489 seconds
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# Read 0 words from page 32/59 in 0.488 seconds
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# Read 0 words from page 33/59 in 0.497 seconds
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# Read 0 words from page 34/59 in 0.482 seconds
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (153 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (158 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (163 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (168 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (173 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# mupdf: object out of range (178 0 R); xref size 151
# ...
# mupdf: object out of range (138 0 R); xref size 46
# mupdf: object out of range (143 0 R); xref size 46
# mupdf: object out of range (143 0 R); xref size 46
# mupdf: object out of range (143 0 R); xref size 46
# mupdf: object out of range (148 0 R); xref size 46
# mupdf: object out of range (148 0 R); xref size 46
# mupdf: object out of range (148 0 R); xref size 46
# mupdf: object out of range (153 0 R); xref size 46
# mupdf: object out of range (153 0 R); xref size 46
# mupdf: object out of range (153 0 R); xref size 46
# mupdf: object out of range (158 0 R); xref size 46
# mupdf: object out of range (158 0 R); xref size 46
# mupdf: object out of range (158 0 R); xref size 46
# mupdf: object out of range (163 0 R); xref size 46
# mupdf: object out of range (163 0 R); xref size 46
# mupdf: object out of range (163 0 R); xref size 46
# mupdf: object out of range (168 0 R); xref size 46
# mupdf: object out of range (168 0 R); xref size 46
# mupdf: object out of range (168 0 R); xref size 46
# mupdf: object out of range (173 0 R); xref size 46
# mupdf: object out of range (173 0 R); xref size 46
# mupdf: object out of range (173 0 R); xref size 46
# mupdf: object out of range (178 0 R); xref size 46
# mupdf: object out of range (178 0 R); xref size 46
# mupdf: object out of range (178 0 R); xref size 46
# mupdf: object out of range (183 0 R); xref size 46
# mupdf: object out of range (183 0 R); xref size 46
# mupdf: object out of range (183 0 R); xref size 46
# mupdf: object out of range (188 0 R); xref size 46
# mupdf: object out of range (188 0 R); xref size 46
# mupdf: object out of range (188 0 R); xref size 46
# mupdf: object out of range (193 0 R); xref size 46
# mupdf: object out of range (193 0 R); xref size 46
# mupdf: object out of range (193 0 R); xref size 46
# mupdf: object out of range (198 0 R); xref size 46
# mupdf: object out of range (198 0 R); xref size 46
# mupdf: object out of range (198 0 R); xref size 46
# mupdf: object out of range (203 0 R); xref size 46
# mupdf: object out of range (203 0 R); xref size 46
# mupdf: object out of range (203 0 R); xref size 46
# mupdf: object out of range (208 0 R); xref size 46
# mupdf: object out of range (208 0 R); xref size 46
# mupdf: object out of range (208 0 R); xref size 46
# mupdf: object out of range (213 0 R); xref size 46
# mupdf: object out of range (213 0 R); xref size 46
# mupdf: object out of range (213 0 R); xref size 46
# mupdf: object out of range (218 0 R); xref size 46
# mupdf: object out of range (218 0 R); xref size 46
# mupdf: object out of range (218 0 R); xref size 46
# mupdf: object out of range (223 0 R); xref size 46
# mupdf: object out of range (223 0 R); xref size 46
# mupdf: object out of range (223 0 R); xref size 46
# mupdf: object out of range (228 0 R); xref size 46
# mupdf: object out of range (228 0 R); xref size 46
# mupdf: object out of range (228 0 R); xref size 46
# mupdf: object out of range (233 0 R); xref size 46
# mupdf: object out of range (233 0 R); xref size 46
# mupdf: object out of range (233 0 R); xref size 46
# mupdf: object out of range (238 0 R); xref size 46
# mupdf: object out of range (238 0 R); xref size 46
# mupdf: object out of range (238 0 R); xref size 46
# mupdf: object out of range (243 0 R); xref size 46
# mupdf: object out of range (243 0 R); xref size 46
# mupdf: object out of range (243 0 R); xref size 46
# mupdf: object out of range (248 0 R); xref size 46
# mupdf: object out of range (248 0 R); xref size 46
# mupdf: object out of range (248 0 R); xref size 46
# mupdf: object out of range (253 0 R); xref size 46
# mupdf: object out of range (253 0 R); xref size 46
# mupdf: object out of range (253 0 R); xref size 46
# mupdf: object out of range (258 0 R); xref size 46
# mupdf: object out of range (258 0 R); xref size 46
# mupdf: object out of range (258 0 R); xref size 46
# mupdf: object out of range (263 0 R); xref size 46
# mupdf: object out of range (263 0 R); xref size 46
# mupdf: object out of range (263 0 R); xref size 46
# mupdf: object out of range (268 0 R); xref size 46
# mupdf: object out of range (268 0 R); xref size 46
# mupdf: object out of range (268 0 R); xref size 46
# mupdf: object out of range (273 0 R); xref size 46
# mupdf: object out of range (273 0 R); xref size 46
# mupdf: object out of range (273 0 R); xref size 46
# mupdf: object out of range (278 0 R); xref size 46
# mupdf: object out of range (278 0 R); xref size 46
# mupdf: object out of range (278 0 R); xref size 46
# mupdf: object out of range (283 0 R); xref size 46
# mupdf: object out of range (283 0 R); xref size 46
# mupdf: object out of range (283 0 R); xref size 46
# mupdf: object out of range (288 0 R); xref size 46
# mupdf: object out of range (288 0 R); xref size 46
# mupdf: object out of range (288 0 R); xref size 46
# mupdf: object out of range (293 0 R); xref size 46
# mupdf: object out of range (293 0 R); xref size 46
# mupdf: object out of range (293 0 R); xref size 46
# mupdf: object out of range (298 0 R); xref size 46
# mupdf: object out of range (298 0 R); xref size 46
# mupdf: object out of range (298 0 R); xref size 46
# mupdf: object out of range (303 0 R); xref size 46
# mupdf: object out of range (303 0 R); xref size 46
# mupdf: object out of range (303 0 R); xref size 46
# mupdf: object out of range (308 0 R); xref size 46
# mupdf: object out of range (308 0 R); xref size 46
# mupdf: object out of range (308 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# mupdf: object out of range (313 0 R); xref size 46
# Progress: 0%|====================|100%
# Completed 018 Daily Trust, Wednesday, July 18, 2007 Vol. 16  No. 93.pdf in 54.974 seconds (59 pages, 3675 words, 0.932 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/07-JULY 2007/019 Daily Trust, Thursday, July 19, 2007  vOL.16 No. 94.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 019 Daily Trust, Thursday, July 19, 2007  vOL.16 No. 94.pdf in 620.41 seconds (56 pages, 65291 words, 11.079 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/07-JULY 2007/020 Daily Trust, Friday, July 20, 2007 Vol. 16 No. 95.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 020 Daily Trust, Friday, July 20, 2007 Vol. 16 No. 95.pdf in 109.366 seconds (56 pages, 53902 words, 1.953 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/07-JULY 2007/021 Weekly Trust, Saturday, July 21, 2007 vol. 10 No 38.pdf (56 pages)
# Progress: 0%|
# mupdf: expected object number
# mupdf: invalid key in dict
# mupdf: cannot parse indirect reference in array
# mupdf: invalid key in dict
# mupdf: invalid key in dict
# mupdf: invalid key in dict
# mupdf: invalid key in dict
# mupdf: invalid key in dict
# mupdf: invalid key in dict
# mupdf: non-page object in page tree
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 021 Weekly Trust, Saturday, July 21, 2007 vol. 10 No 38.pdf in 579.29 seconds (56 pages, 69542 words, 10.344 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/07-JULY 2007/022 Sunday Trust, Vol. 1 No. 42 July 22, 2007 Rajab 8, 1428 A. H. - Copy.pdf (64 pages)
# Progress: 0%|====================|100%
# Completed 022 Sunday Trust, Vol. 1 No. 42 July 22, 2007 Rajab 8, 1428 A. H. - Copy.pdf in 1.265 seconds (64 pages, 74877 words, 0.02 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/07-JULY 2007/023 Daily Trust, Monday, July 23, 2007  Vol. 16  No. 96.pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 023 Daily Trust, Monday, July 23, 2007  Vol. 16  No. 96.pdf in 316.951 seconds (64 pages, 74098 words, 4.952 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/07-JULY 2007/024 Daily Trust, Tuesday, July 24, 2007 Vol.16 No. 97.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 024 Daily Trust, Tuesday, July 24, 2007 Vol.16 No. 97.pdf in 589.003 seconds (56 pages, 63998 words, 10.518 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/07-JULY 2007/025 Daily Trust, Wednesday, July 25, 2007 Vol. 16 No. 98.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 025 Daily Trust, Wednesday, July 25, 2007 Vol. 16 No. 98.pdf in 102.718 seconds (56 pages, 54700 words, 1.834 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/07-JULY 2007/026 Daily Trust, Thursday, July 26, 2007 Vol.  16 No.99.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 026 Daily Trust, Thursday, July 26, 2007 Vol.  16 No.99.pdf in 542.774 seconds (56 pages, 59871 words, 9.692 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/07-JULY 2007/027 Daily Trust, Friday, July 27, 2007 Vol. 16 No. 100.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 027 Daily Trust, Friday, July 27, 2007 Vol. 16 No. 100.pdf in 127.31 seconds (56 pages, 51944 words, 2.273 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/07-JULY 2007/028 Weekly Trust, Saturday, July 28, 2007 vol. 10 No 39.pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 028 Weekly Trust, Saturday, July 28, 2007 vol. 10 No 39.pdf in 655.92 seconds (64 pages, 77835 words, 10.249 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/07-JULY 2007/029 Sunday Trust, Vol. 1 No. 44 July 29, 2007 Rajab 15, 1428 A .H..pdf (64 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 029 Sunday Trust, Vol. 1 No. 44 July 29, 2007 Rajab 15, 1428 A .H..pdf in 4.149 seconds (64 pages, 77805 words, 0.065 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/07-JULY 2007/030 Daily Trust, Monday, July 30, 2007 Vol. 17 No. 1.pdf (64 pages)
# Progress: 0%|====================|100%
# Completed 030 Daily Trust, Monday, July 30, 2007 Vol. 17 No. 1.pdf in 1.032 seconds (64 pages, 61342 words, 0.016 seconds/page)
#
# Processing /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY/07-JULY 2007/031 Daily Trust, Tuesday, July 31, 2007 Vol. 17 No. 2.pdf (56 pages)
# This file contains pages without machine-readable text, attempting to process (This may take a few seconds per page).
# Progress: 0%|====================|100%
# Completed 031 Daily Trust, Tuesday, July 31, 2007 Vol. 17 No. 2.pdf in 615.746 seconds (56 pages, 69087 words, 10.995 seconds/page)
#
# The file /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY.csv contains all of the text extracted from all PDF files in /Users/danielwhitten/Documents/CCD/PDFs/MAY-JULY
# 89 files (5889367 words) were processed in 43739.286 seconds. That is an average of 491.453 seconds/file

# %% [markdown]
# _Just in case you accidentally erased the command above, here it is again for you to copy and paste:_
# `%run PDFtoCSV.py "example/path/to/folder/with/PDFs"`

# %% [markdown]
# ## Troubleshooting Common Issues

# %% [markdown]
# ### Please enter a valid file or directory / The folder you have entered does not contain any PDF files
# * Include the full and exact spelling and syntax of the path to your file or folder. The best way to ensure this is to copy it directly, here's how:
#     * Open the folder containing the folder or file you want to copy
#     * On Windows:
#       * Hold Shift and right click on the folder or file
#       * Left click on the menu option "Copy as Path"
#     * On MacOS
#       * Right click on the folder or file
#       * Hold the Option button
#       * Left click on the menu option "Copy [name] as Pathname"
#     * Paste in the cell above, replacing `"path/to/folder/with/PDF"`
#     * Be sure to put a quotation mark before **and** after the path you have pasted
#     * Press Shift + Enter to run the program
#
# ### There appears to be an issue with your Tesseract OCR installation
# * Refer to 1. under the "Installation" section of this guide on how to install Tesseract OCR. If you have it installed, try uninstalling and re-installing, being sure to accept all default options on the installation.
#
# ### I could not find your Tesseract-OCR installation in the default location.
# * Refer to 1. under the "Installation section of this guide on how to install Tesseract OCR.
# * Open the file `tesseractPath.txt` in the same folder as this file, and follow the instructions there to locate your Tesseract program on Linux, or if it was installed in a non-default location on Windows or MacOS.
#
# ### Other issues
# This program is still in very early development, and at this point is not fully complete with robust error handling or options for non-standard situations. We attempted to make it as broadly usable as possible. Hopefully further versions will come that include more detailed options for handling unexpected issues.
#
# Please feel free to contact me at danieljwhitten@gmail.com, if you have any small issues that I might easily be able to provide advice on.
